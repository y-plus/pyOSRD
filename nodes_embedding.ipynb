# %%
import networkx as nx
from schedules import Schedule

# %%
from fixtures import *

# %%
three_trains().graph.nodes[2]
# Out:
# {'times': array([1, 2, 2, 3, 3, 4])}

# %%
G = three_trains().graph

# %%
schedule = three_trains()

# %%
# schedule._df.at[6,0] = [-1,0]
# schedule._df.at[7,1] = [0,1]
# schedule._df.at[8,2] = [1,2]

# %%
schedule.draw_graph()
