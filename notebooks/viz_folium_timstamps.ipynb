# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pyosrd import OSRD
small_infra = OSRD('./cases/small_infra/')

# %%
small_infra = OSRD('./cases/small_infra/')

# %%
small_infra.run()
# Out:
# [07:15:27,494] [INFO]  [StandaloneSimulationCommand] Loading infra: ./cases/small_infra/infra.json
# [07:15:27,535] [INFO]              [FullInfra] parsing infra
# [07:15:27,640] [INFO]              [FullInfra] adaptation to kotlin
# [07:15:27,695] [INFO]              [FullInfra] loading signals
# [07:15:27,704] [INFO]              [FullInfra] building blocks
# [07:15:27,713] [INFO]  [StandaloneSimulationCommand] Loading input: ./cases/small_infra/simulation.json
# [07:15:27,731] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.0
# [07:15:27,809] [DEBUG]             [Allowance] computing range n°1
# [07:15:27,812] [DEBUG]             [Allowance]   computing section n°1
# [07:15:27,812] [DEBUG]             [Allowance]   target time = 353.40375
# [07:15:27,812] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,815] [DEBUG]             [Allowance]     envelope time 596.245
# [07:15:27,815] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,815] [DEBUG]             [Allowance]     envelope time 430.145
# [07:15:27,815] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,815] [DEBUG]             [Allowance]     envelope time 377.638
# [07:15:27,816] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,816] [DEBUG]             [Allowance]     envelope time 355.929
# [07:15:27,816] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,816] [DEBUG]             [Allowance]     envelope time 345.832
# [07:15:27,816] [DEBUG]             [Allowance]     starting attempt 6
# [07:15:27,816] [DEBUG]             [Allowance]     envelope time 350.88
# [07:15:27,816] [DEBUG]             [Allowance]     starting attempt 7
# [07:15:27,816] [DEBUG]             [Allowance]     envelope time 353.404
# [07:15:27,816] [DEBUG]             [Allowance]   computing section n°2
# [07:15:27,817] [DEBUG]             [Allowance]   target time = 608.2314
# [07:15:27,817] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,817] [DEBUG]             [Allowance]     envelope time 1049.057
# [07:15:27,817] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,817] [DEBUG]             [Allowance]     envelope time 746.388
# [07:15:27,817] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,817] [DEBUG]             [Allowance]     envelope time 652.256
# [07:15:27,817] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,817] [DEBUG]             [Allowance]     envelope time 613.446
# [07:15:27,817] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,817] [DEBUG]             [Allowance]     envelope time 595.779
# [07:15:27,818] [DEBUG]             [Allowance]     starting attempt 6
# [07:15:27,818] [DEBUG]             [Allowance]     envelope time 604.468
# [07:15:27,818] [DEBUG]             [Allowance]     starting attempt 7
# [07:15:27,818] [DEBUG]             [Allowance]     envelope time 609.101
# [07:15:27,818] [DEBUG]             [Allowance]   computing section n°3
# [07:15:27,818] [DEBUG]             [Allowance]   target time = 270.3435
# [07:15:27,818] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,818] [DEBUG]             [Allowance]     envelope time 445.425
# [07:15:27,818] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,819] [DEBUG]             [Allowance]     envelope time 326.217
# [07:15:27,819] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,819] [DEBUG]             [Allowance]     envelope time 287.725
# [07:15:27,819] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,819] [DEBUG]             [Allowance]     envelope time 271.76
# [07:15:27,827] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.1
# [07:15:27,834] [DEBUG]             [Allowance] computing range n°1
# [07:15:27,835] [DEBUG]             [Allowance]   computing section n°1
# [07:15:27,835] [DEBUG]             [Allowance]   target time = 353.40375
# [07:15:27,835] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,836] [DEBUG]             [Allowance]     envelope time 360.901
# [07:15:27,836] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,837] [DEBUG]             [Allowance]     envelope time 336.626
# [07:15:27,837] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,837] [DEBUG]             [Allowance]     envelope time 342.206
# [07:15:27,837] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,837] [DEBUG]             [Allowance]     envelope time 349.1
# [07:15:27,837] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,837] [DEBUG]             [Allowance]     envelope time 354.311
# [07:15:27,837] [DEBUG]             [Allowance]   computing section n°2
# [07:15:27,837] [DEBUG]             [Allowance]   target time = 393.8004
# [07:15:27,837] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,838] [DEBUG]             [Allowance]     envelope time 402.532
# [07:15:27,838] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,838] [DEBUG]             [Allowance]     envelope time 375.095
# [07:15:27,838] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,838] [DEBUG]             [Allowance]     envelope time 381.281
# [07:15:27,838] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,838] [DEBUG]             [Allowance]     envelope time 389.495
# [07:15:27,838] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,838] [DEBUG]             [Allowance]     envelope time 395.324
# [07:15:27,838] [DEBUG]             [Allowance]   computing section n°3
# [07:15:27,838] [DEBUG]             [Allowance]   target time = 496.03785
# [07:15:27,838] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,839] [DEBUG]             [Allowance]     envelope time 502.942
# [07:15:27,839] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,839] [DEBUG]             [Allowance]     envelope time 472.46
# [07:15:27,839] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,839] [DEBUG]             [Allowance]     envelope time 479.046
# [07:15:27,839] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,839] [DEBUG]             [Allowance]     envelope time 488.074
# [07:15:27,839] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,840] [DEBUG]             [Allowance]     envelope time 494.574
# [07:15:27,843] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.2
# [07:15:27,852] [DEBUG]             [Allowance] computing range n°1
# [07:15:27,852] [DEBUG]             [Allowance]   computing section n°1
# [07:15:27,852] [DEBUG]             [Allowance]   target time = 408.575
# [07:15:27,852] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,852] [DEBUG]             [Allowance]     envelope time 596.245
# [07:15:27,852] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,852] [DEBUG]             [Allowance]     envelope time 430.145
# [07:15:27,852] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,852] [DEBUG]             [Allowance]     envelope time 377.638
# [07:15:27,853] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,853] [DEBUG]             [Allowance]     envelope time 402.208
# [07:15:27,853] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,853] [DEBUG]             [Allowance]     envelope time 415.672
# [07:15:27,853] [DEBUG]             [Allowance]     starting attempt 6
# [07:15:27,853] [DEBUG]             [Allowance]     envelope time 408.939
# [07:15:27,853] [DEBUG]             [Allowance]   computing section n°2
# [07:15:27,853] [DEBUG]             [Allowance]   target time = 462.048
# [07:15:27,853] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,853] [DEBUG]             [Allowance]     envelope time 667.398
# [07:15:27,853] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,853] [DEBUG]             [Allowance]     envelope time 480.249
# [07:15:27,854] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,854] [DEBUG]             [Allowance]     envelope time 421.179
# [07:15:27,854] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,854] [DEBUG]             [Allowance]     envelope time 448.745
# [07:15:27,854] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,854] [DEBUG]             [Allowance]     envelope time 463.934
# [07:15:27,854] [DEBUG]             [Allowance]   computing section n°3
# [07:15:27,854] [DEBUG]             [Allowance]   target time = 502.866
# [07:15:27,854] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,854] [DEBUG]             [Allowance]     envelope time 722.926
# [07:15:27,854] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,855] [DEBUG]             [Allowance]     envelope time 518.164
# [07:15:27,855] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,855] [DEBUG]             [Allowance]     envelope time 453.948
# [07:15:27,855] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,855] [DEBUG]             [Allowance]     envelope time 483.837
# [07:15:27,855] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,855] [DEBUG]             [Allowance]     envelope time 500.394
# [07:15:27,855] [DEBUG]             [Allowance]     starting attempt 6
# [07:15:27,855] [DEBUG]             [Allowance]     envelope time 509.078
# [07:15:27,855] [DEBUG]             [Allowance]     starting attempt 7
# [07:15:27,855] [DEBUG]             [Allowance]     envelope time 504.835
# [07:15:27,859] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.3
# [07:15:27,865] [DEBUG]             [Allowance] computing range n°1
# [07:15:27,865] [DEBUG]             [Allowance]   computing section n°1
# [07:15:27,865] [DEBUG]             [Allowance]   target time = 427.0350474283088
# [07:15:27,865] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,865] [DEBUG]             [Allowance]     envelope time 596.245
# [07:15:27,865] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,865] [DEBUG]             [Allowance]     envelope time 430.145
# [07:15:27,865] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,865] [DEBUG]             [Allowance]     envelope time 377.638
# [07:15:27,865] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,866] [DEBUG]             [Allowance]     envelope time 402.208
# [07:15:27,866] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,866] [DEBUG]             [Allowance]     envelope time 415.672
# [07:15:27,866] [DEBUG]             [Allowance]     starting attempt 6
# [07:15:27,866] [DEBUG]             [Allowance]     envelope time 422.907
# [07:15:27,866] [DEBUG]             [Allowance]     starting attempt 7
# [07:15:27,866] [DEBUG]             [Allowance]     envelope time 426.442
# [07:15:27,866] [DEBUG]             [Allowance]   computing section n°2
# [07:15:27,866] [DEBUG]             [Allowance]   target time = 476.7643460510602
# [07:15:27,866] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,866] [DEBUG]             [Allowance]     envelope time 668.872
# [07:15:27,866] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,866] [DEBUG]             [Allowance]     envelope time 481.174
# [07:15:27,866] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,866] [DEBUG]             [Allowance]     envelope time 421.991
# [07:15:27,866] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,866] [DEBUG]             [Allowance]     envelope time 449.61
# [07:15:27,866] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,866] [DEBUG]             [Allowance]     envelope time 464.828
# [07:15:27,867] [DEBUG]             [Allowance]     starting attempt 6
# [07:15:27,867] [DEBUG]             [Allowance]     envelope time 472.908
# [07:15:27,867] [DEBUG]             [Allowance]     starting attempt 7
# [07:15:27,867] [DEBUG]             [Allowance]     envelope time 476.853
# [07:15:27,867] [DEBUG]             [Allowance]   computing section n°3
# [07:15:27,867] [DEBUG]             [Allowance]   target time = 512.4116065206309
# [07:15:27,867] [DEBUG]             [Allowance]     starting attempt 1
# [07:15:27,867] [DEBUG]             [Allowance]     envelope time 722.926
# [07:15:27,867] [DEBUG]             [Allowance]     starting attempt 2
# [07:15:27,867] [DEBUG]             [Allowance]     envelope time 518.164
# [07:15:27,867] [DEBUG]             [Allowance]     starting attempt 3
# [07:15:27,867] [DEBUG]             [Allowance]     envelope time 453.948
# [07:15:27,867] [DEBUG]             [Allowance]     starting attempt 4
# [07:15:27,867] [DEBUG]             [Allowance]     envelope time 483.837
# [07:15:27,868] [DEBUG]             [Allowance]     starting attempt 5
# [07:15:27,868] [DEBUG]             [Allowance]     envelope time 500.394
# [07:15:27,868] [DEBUG]             [Allowance]     starting attempt 6
# [07:15:27,868] [DEBUG]             [Allowance]     envelope time 509.078
# [07:15:27,868] [DEBUG]             [Allowance]     starting attempt 7
# [07:15:27,868] [DEBUG]             [Allowance]     envelope time 513.521
# [07:15:27,871] [INFO]  [StandaloneSimulationCommand] All simulations completed
# [07:15:27,872] [INFO]  [StandaloneSimulationCommand] Saving results at: ./cases/small_infra/results.json

# %%
from pyosrd.viz.map import folium_map

# %%
ax = small_infra.space_time_chart(
    0,
    points_to_show=['station',],
    eco_or_base='base',
)
ax.set_xlim(left=min(small_infra.departure_times)/60.)
# Out:
# (600.0, 682.4868333236357)

# %%
self=small_infra
train=2

# %%
import numpy as np
from pyosrd.osrd import Point
import pandas as pd
import folium
from haversine import haversine

# %%
additional_records = []

times = [record['time'] for record in self._head_position(train)]
offsets = [
    self.offset_in_path_of_train(
        Point(
            track_section=record['track_section'],
            position=record['path_offset']
        ),
        train
    )
    for record in self._head_position(train)
]

for track in small_infra.train_track_sections(train):

    track_section = [t for t in small_infra.infra['track_sections'] if t['id']==track['id']][0]
    path_offset_begin = small_infra.offset_in_path_of_train(
            Point(track_section=track_section['id'], position=0), train
        )
    path_offset_end = small_infra.offset_in_path_of_train(
            Point(track_section=track_section['id'], position=track_section['length']),
            train=train,
        )
    additional_records+=([{
        'track_section': track_section['id'],
        'offset': 0,
        'path_offset': path_offset_begin,
        'time': np.interp(path_offset_begin, offsets, times).item()
    },  {
        'track_section': track_section['id'],
        'offset':track_section['length'],
        'path_offset': path_offset_end,
        'time': np.interp(path_offset_end, offsets, times).item()
    }])

# %%
additional_records = []

# %%
track_section_coordinates = {
    ts['id']: [(point[1], point[0]) for point in ts['geo']['coordinates']]
    for ts in self.infra['track_sections']
}

track_section_geo_lengths = {
    ts['id']: haversine(
        (
            ts['geo']['coordinates'][0][1],
            ts['geo']['coordinates'][0][0]
        ),
        (
            ts['geo']['coordinates'][-1][1],
            ts['geo']['coordinates'][-1][0]
        ),
        unit='m'
    )
    for ts in self.infra['track_sections']
    }

def coords_from_position_on_track(
    track_section: str,
    position: float,
) -> list[float]:
    length = self.track_section_lengths[track_section]
    pos = position / length
    positions = [
        haversine(
            point, track_section_coordinates[track_section][0], unit='m'
        )
        / track_section_geo_lengths[track_section]
        for point in track_section_coordinates[track_section]
    ]
    lats = [coord[0] for coord in track_section_coordinates[track_section]]
    lngs = [coord[1] for coord in track_section_coordinates[track_section]]
    return [
        np.interp([pos], positions, lats).item(),
        np.interp([pos], positions, lngs).item(),
    ]

records = [r for r in self._head_position(train) + additional_records if r['path_offset'] is not None]
records.sort(key=lambda x: x['path_offset'])
for r in records:
    r['lat'], r['long'] = coords_from_position_on_track(r['track_section'], r['offset'])
    
lats = [r['lat'] for r in records]
longs = [r['long'] for r in records]
times = [r['time'] for r in records]
times_ = np.arange(start=records[0]['time'], stop=max(times), step=5)
coords_ = list(zip(np.interp(times_, times, longs), np.interp(times_, times, lats)))

# %%
m = folium_map(small_infra)
folium.plugins.TimestampedGeoJson(
    {
        "type": "FeatureCollection",
        "features": [
            {
                "type": "Feature",
                "geometry": {
                    "type": "MultiPoint",
                    "coordinates": coords_, #[[r['long'], r['lat']] for r in records],
                },
                "properties": {
                    'times': [str(pd.to_datetime('today').normalize() + pd.DateOffset(seconds=t)) for t in times_],
                    "tooltip": "train_0",
                    "icon": "circle",
                    "iconstyle": {
                        "fillColor": "blue",
                        "fillOpacity": 1,
                        "stroke": "false",
                        # "radius": 13,
                    },
                    "style": {"weight": 0}, 
                },
            },
            {
                "type": "Feature",
                "geometry": {
                    "type": "MultiPoint",
                    "coordinates": coords_, #[[r['long'], r['lat']] for r in records],
                },
                "properties": {
                    'times': [str(pd.to_datetime('today').normalize() + pd.DateOffset(seconds=t+3*60.)) for t in times_],
                    "tooltip": "train_plus_3",
                    "icon": "circle",
                    "iconstyle": {
                        "fillColor": "orange",
                        "fillOpacity": 1,
                        "stroke": "false",
                        # "radius": 13,
                    },
                    "style": {"weight": 0}, 
                },
            },
        ],
    },
    loop=False,
    duration='PT5S',
    period='PT5S',
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f624f2a2e473b069a462b30c7f7c9fad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f624f2a2e473b069a462b30c7f7c9fad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f624f2a2e473b069a462b30c7f7c9fad = L.map(
#                 &quot;map_f624f2a2e473b069a462b30c7f7c9fad&quot;,
#                 {
#                     center: [49.5, -0.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23aceb07f55b8c300f86d63a9e779ba9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_23aceb07f55b8c300f86d63a9e779ba9.addTo(map_f624f2a2e473b069a462b30c7f7c9fad);
#
#
#             var feature_group_94cd3007fca41b45713e6ac9cafe4b6c = L.featureGroup(
#                 {}
#             );
#
#
#             var poly_line_64ee9ead23d8ec9d8b700733ebe0cd8b = L.polyline(
#                 [[49.5, -0.4], [49.5, -0.365]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_94cd3007fca41b45713e6ac9cafe4b6c);
#
#
#             poly_line_64ee9ead23d8ec9d8b700733ebe0cd8b.bindTooltip(
#                 `&lt;div&gt;
#                      V1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_ff9d02bfbcef7369e15a886f2fbfac63 = L.polyline(
#                 [[49.4999, -0.4], [49.4999, -0.37]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_94cd3007fca41b45713e6ac9cafe4b6c);
#
#
#             poly_line_ff9d02bfbcef7369e15a886f2fbfac63.bindTooltip(
#                 `&lt;div&gt;
#                      V2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_39e47005c7bb2a8661a340e08266bc94 = L.polyline(
#                 [[49.49979999999999, -0.4], [49.49979999999999, -0.37]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_94cd3007fca41b45713e6ac9cafe4b6c);
#
#
#             poly_line_39e47005c7bb2a8661a340e08266bc94.bindTooltip(
#                 `&lt;div&gt;
#                      A
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
