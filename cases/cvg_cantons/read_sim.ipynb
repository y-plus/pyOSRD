# %%
import rlway.osrd.infra as infr
import matplotlib.pyplot as plt

# %%
infra, sim, res = infr.read_jsons_in_dir('.')

# %%
from rlway.schedules import Schedule, schedule_from_simulation

# %%
s = schedule_from_simulation(infra, res, simplify_route_names=True)
s.draw_graph()

# %%
s = s.sort()

# %%
s.plot()

# %%
s.df
# Out:
#                    0
#                    s        e
# STOP.0->DA1      0.0   45.837
# CVG           12.024     49.5
# DA_out->D0    21.982  114.625
# D0->D1       104.164  190.309
# D1->D2       164.277   411.52
# D2->D3       399.628  459.495
# D3->DB_in    450.568  537.106
# DVG          509.029  548.082
# DB1->STOP.2  512.047  555.751
# STOP.1->DA2      NaN      NaN
# DB2->STOP.3      NaN      NaN

# %%
s.shift_train_after(1,0,'CVG').plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/regul/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/regul/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/regul/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s.shift_train_after(1,0,'CVG').plot()
#
# File ~/regul/src/rlway/schedules.py:197, in Schedule.shift_train_after(self, train1, train2, track_section)
#     194 def shift_train_after(self, train1: int, train2: int, track_section: int) -> 'Schedule':
#     195     """Train1 waits until train has freed track_section"""
# --> 197     train1_waits_at = self.previous_track_section(train1, track_section)
#     199     # If the track section is the departure, it has no previous track section
#     200     if train1_waits_at is None:
#
# File ~/regul/src/rlway/schedules.py:88, in Schedule.previous_track_section(self, train, track_section)
#      86 def previous_track_section(self, train: int, track_section: int) -> Union[int, None]:
# ---> 88     t = self.trajectory(train)
#      89     idx = list(t).index(track_section)
#      91     if idx != 0:
#
# File ~/regul/src/rlway/schedules.py:81, in Schedule.trajectory(self, train)
#      79 def trajectory(self, train: int) -> List[int]:
#      80     return list(
# ---> 81         self.starts[train][self.starts[train].notna()]
#      82         .sort_values()
#      83         .index
#      84     )
#
# File ~/regul/venv/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/regul/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 1

# %%
infr.route_lengths(infra)
# Out:
# {'rt.DA1->DA_out': 70.0,
#  'rt.buffer_stop.0->DA1': 430.0,
#  'rt.DA2->DA_out': 70.0,
#  'rt.buffer_stop.1->DA2': 430.0,
#  'rt.DA_out->D0': 1950.0,
#  'rt.D0->D1': 2000.0,
#  'rt.D1->D2': 2000.0,
#  'rt.D2->D3': 2000.0,
#  'rt.D3->DB_in': 1970.0,
#  'rt.DB_in->DB2': 60.0,
#  'rt.DB_in->DB1': 60.0,
#  'rt.DB1->buffer_stop.2': 420.0,
#  'rt.DB2->buffer_stop.3': 420.0}

# %%
infr.route_lengths(infra)
# Out:
# {'rt.DA1->DA_out': 70.0,
#  'rt.buffer_stop.0->DA1': 430.0,
#  'rt.DA2->DA_out': 70.0,
#  'rt.buffer_stop.1->DA2': 430.0,
#  'rt.DA_out->D0': 1950.0,
#  'rt.D0->D1': 2000.0,
#  'rt.D1->D2': 2000.0,
#  'rt.D2->D3': 2000.0,
#  'rt.D3->DB_in': 1970.0,
#  'rt.DB_in->DB2': 60.0,
#  'rt.DB_in->DB1': 60.0,
#  'rt.DB1->buffer_stop.2': 420.0,
#  'rt.DB2->buffer_stop.3': 420.0}

# %%
base_head_positions = res[0]['base_simulations'][0]['head_positions']
eco_head_positions = res[0]['eco_simulations'][0]['head_positions']

t_base = [dict['time'] for dict in base_head_positions]
y_base = [dict['path_offset'] for dict in base_head_positions]
t_eco = [dict['time'] for dict in eco_head_positions]
y_eco = [dict['path_offset'] for dict in eco_head_positions]
plt.plot(t_base, y_base, label='base')
plt.plot(t_eco, y_eco, label='eco')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
base_speeds = res[0]['base_simulations'][0]['speeds']
eco_speeds = res[0]['eco_simulations'][0]['speeds']
t__base = [dict['time'] for dict in base_speeds]
y__base = [dict['speed'] for dict in base_speeds]
t__eco = [dict['time'] for dict in eco_speeds]
y__eco = [dict['speed'] for dict in eco_speeds]
plt.plot(t__base, y__base, label='base')
plt.plot(t__eco, y__eco, label='eco')
plt.legend()
plt.xlabel('Time')
plt.ylabel('speed')
# Out:
# Text(0, 0.5, 'speed')

# %%
infr.route_limits(infra)
# Out:
# {'DA1': ('STA_Q1', 430.0),
#  'DA2': ('STA_Q2', 430.0),
#  'DA_out': ('T', 50.0),
#  'D0': ('T', 2000.0),
#  'D1': ('T', 4000.0),
#  'D2': ('T', 6000.0),
#  'D3': ('T', 8000.0),
#  'DB_in': ('T', 9970.0),
#  'DB1': ('STB_Q1', 30.0),
#  'DB2': ('STB_Q2', 30.0),
#  'buffer_stop.0': ('STA_Q1', 0.0),
#  'buffer_stop.1': ('STA_Q2', 0.0),
#  'buffer_stop.2': ('STB_Q1', 450.0),
#  'buffer_stop.3': ('STB_Q2', 450.0)}

# %%
res[0]['base_simulations']
# Out:
# [{'head_positions': [{'offset': 400.0,
#     'path_offset': 0.0,
#     'time': 0.0,
#     'track_section': 'STA_Q1'},
#    {'offset': 408.29372207539166,
#     'path_offset': 8.293722075391658,
#     'time': 6.0,
#     'track_section': 'STA_Q1'},
#    {'offset': 445.0655840853055,
#     'path_offset': 45.065584085305474,
#     'time': 14.0,
#     'track_section': 'STA_Q1'},
#    {'offset': 61.014205997204684,
#     'path_offset': 111.01420599720468,
#     'time': 22.0,
#     'track_section': 'T'},
#    {'offset': 155.8111505355178,
#     'path_offset': 205.8111505355178,
#     'time': 30.0,
#     'track_section': 'T'},
#    {'offset': 245.53552366585438,
#     'path_offset': 295.5355236658544,
#     'time': 36.0,
#     'track_section': 'T'},
#    {'offset': 389.1804084229013,
#     'path_offset': 439.1804084229013,
#     'time': 44.0,
#     'track_section': 'T'},
#    {'offset': 558.4010599865563,
#     'path_offset': 608.4010599865563,
#     'time': 52.0,
#     'track_section': 'T'},
#    {'offset': 750.5561023962644,
#     'path_offset': 800.5561023962644,
#     'time': 60.0,
#     'track_section': 'T'},
#    {'offset': 909.3464399779697,
#     'path_offset': 959.3464399779697,
#     'time': 66.0,
#     'track_section': 'T'},
#    {'offset': 1140.4351510240772,
#     'path_offset': 1190.4351510240772,
#     'time': 74.0,
#     'track_section': 'T'},
#    {'offset': 1393.488407958817,
#     'path_offset': 1443.488407958817,
#     'time': 82.0,
#     'track_section': 'T'},
#    {'offset': 1668.2792793467538,
#     'path_offset': 1718.2792793467538,
#     'time': 90.0,
#     'track_section': 'T'},
#    {'offset': 1888.4677897851884,
#     'path_offset': 1938.4677897851884,
#     'time': 96.0,
#     'track_section': 'T'},
#    {'offset': 2200.5132668861165,
#     'path_offset': 2250.5132668861165,
#     'time': 104.0,
#     'track_section': 'T'},
#    {'offset': 2736.0,
#     'path_offset': 2786.0,
#     'time': 116.7308645707014,
#     'track_section': 'T'},
#    {'offset': 2979.0,
#     'path_offset': 3029.0,
#     'time': 122.7308645707014,
#     'track_section': 'T'},
#    {'offset': 3204.0,
#     'path_offset': 3254.0,
#     'time': 128.73086457070139,
#     'track_section': 'T'},
#    {'offset': 3476.0,
#     'path_offset': 3526.0,
#     'time': 136.73086457070139,
#     'track_section': 'T'},
#    {'offset': 3716.0,
#     'path_offset': 3766.0,
#     'time': 144.73086457070139,
#     'track_section': 'T'},
#    {'offset': 3824.0,
#     'path_offset': 3874.0,
#     'time': 148.73086457070139,
#     'track_section': 'T'},
#    {'offset': 3971.0,
#     'path_offset': 4021.0,
#     'time': 154.73086457070139,
#     'track_section': 'T'},
#    {'offset': 4139.0,
#     'path_offset': 4189.0,
#     'time': 162.73086457070139,
#     'track_section': 'T'},
#    {'offset': 4211.0,
#     'path_offset': 4261.0,
#     'time': 166.73086457070139,
#     'track_section': 'T'},
#    {'offset': 4304.0,
#     'path_offset': 4354.0,
#     'time': 172.73086457070139,
#     'track_section': 'T'},
#    {'offset': 4379.0,
#     'path_offset': 4429.0,
#     'time': 178.73086457070139,
#     'track_section': 'T'},
#    {'offset': 4436.0,
#     'path_offset': 4486.0,
#     'time': 184.73086457070139,
#     'track_section': 'T'},
#    {'offset': 4475.0,
#     'path_offset': 4525.0,
#     'time': 190.73086457070139,
#     'track_section': 'T'},
#    {'offset': 4496.0,
#     'path_offset': 4546.0,
#     'time': 196.73086457070139,
#     'track_section': 'T'},
#    {'offset': 4500.0,
#     'path_offset': 4550.0,
#     'time': 300.7308645707014,
#     'track_section': 'T'},
#    {'offset': 4514.737564131869,
#     'path_offset': 4564.737564131869,
#     'time': 308.7308645707014,
#     'track_section': 'T'},
#    {'offset': 4558.828024738028,
#     'path_offset': 4608.828024738028,
#     'time': 316.7308645707014,
#     'track_section': 'T'},
#    {'offset': 4591.8069436487185,
#     'path_offset': 4641.8069436487185,
#     'time': 320.7308645707014,
#     'track_section': 'T'},
#    {'offset': 4654.834363742604,
#     'path_offset': 4704.834363742604,
#     'time': 326.7308645707014,
#     'track_section': 'T'},
#    {'offset': 4763.876715061479,
#     'path_offset': 4813.876715061479,
#     'time': 334.7308645707014,
#     'track_section': 'T'},
#    {'offset': 4828.917725684901,
#     'path_offset': 4878.917725684901,
#     'time': 338.7308645707014,
#     'track_section': 'T'},
#    {'offset': 4939.180408422901,
#     'path_offset': 4989.180408422901,
#     'time': 344.7308645707014,
#     'track_section': 'T'},
#    {'offset': 5063.887210602946,
#     'path_offset': 5113.887210602946,
#     'time': 350.7308645707014,
#     'track_section': 'T'},
#    {'offset': 5201.6683698059915,
#     'path_offset': 5251.6683698059915,
#     'time': 356.7308645707014,
#     'track_section': 'T'},
#    {'offset': 5352.0961623123285,
#     'path_offset': 5402.0961623123285,
#     'time': 362.7308645707014,
#     'track_section': 'T'},
#    {'offset': 5515.049360774037,
#     'path_offset': 5565.049360774037,
#     'time': 368.7308645707014,
#     'track_section': 'T'},
#    {'offset': 5690.435151024076,
#     'path_offset': 5740.435151024076,
#     'time': 374.7308645707014,
#     'track_section': 'T'},
#    {'offset': 5878.176865947894,
#     'path_offset': 5928.176865947894,
#     'time': 380.7308645707014,
#     'track_section': 'T'},
#    {'offset': 6078.183637413782,
#     'path_offset': 6128.183637413782,
#     'time': 386.7308645707014,
#     'track_section': 'T'},
#    {'offset': 6290.341198246589,
#     'path_offset': 6340.341198246589,
#     'time': 392.7308645707014,
#     'track_section': 'T'},
#    {'offset': 6670.54946979309,
#     'path_offset': 6720.54946979309,
#     'time': 402.7308645707014,
#     'track_section': 'T'},
#    {'offset': 6914.293479099583,
#     'path_offset': 6964.293479099583,
#     'time': 408.7308645707014,
#     'track_section': 'T'},
#    {'offset': 7169.4445950702975,
#     'path_offset': 7219.4445950702975,
#     'time': 414.7308645707014,
#     'track_section': 'T'},
#    {'offset': 7619.0972831968475,
#     'path_offset': 7669.0972831968475,
#     'time': 424.7308645707014,
#     'track_section': 'T'},
#    {'offset': 8324.0,
#     'path_offset': 8374.0,
#     'time': 439.5347353437818,
#     'track_section': 'T'},
#    {'offset': 8504.0,
#     'path_offset': 8554.0,
#     'time': 443.5347353437818,
#     'track_section': 'T'},
#    {'offset': 8759.0,
#     'path_offset': 8809.0,
#     'time': 449.5347353437818,
#     'track_section': 'T'},
#    {'offset': 8996.0,
#     'path_offset': 9046.0,
#     'time': 455.5347353437818,
#     'track_section': 'T'},
#    {'offset': 9215.0,
#     'path_offset': 9265.0,
#     'time': 461.5347353437818,
#     'track_section': 'T'},
#    {'offset': 9416.0,
#     'path_offset': 9466.0,
#     'time': 467.5347353437818,
#     'track_section': 'T'},
#    {'offset': 9599.0,
#     'path_offset': 9649.0,
#     'time': 473.5347353437818,
#     'track_section': 'T'},
#    {'offset': 9764.0,
#     'path_offset': 9814.0,
#     'time': 479.5347353437818,
#     'track_section': 'T'},
#    {'offset': 9956.0,
#     'path_offset': 10006.0,
#     'time': 487.5347353437818,
#     'track_section': 'T'},
#    {'offset': 116.0,
#     'path_offset': 10166.0,
#     'time': 495.5347353437818,
#     'track_section': 'STB_Q1'},
#    {'offset': 244.0,
#     'path_offset': 10294.0,
#     'time': 503.5347353437818,
#     'track_section': 'STB_Q1'},
#    {'offset': 319.0,
#     'path_offset': 10369.0,
#     'time': 509.5347353437818,
#     'track_section': 'STB_Q1'},
#    {'offset': 391.0,
#     'path_offset': 10441.0,
#     'time': 517.5347353437818,
#     'track_section': 'STB_Q1'},
#    {'offset': 431.0,
#     'path_offset': 10481.0,
#     'time': 525.5347353437818,
#     'track_section': 'STB_Q1'},
#    {'offset': 440.0,
#     'path_offset': 10490.0,
#     'time': 532.5347353437818,
#     'track_section': 'STB_Q1'}],
#   'mechanical_energy_consumed': 2182990633.696049,
#   'route_occupancies': {'rt.D3->DB_in': {'time_head_free': 488.174,
#     'time_head_occupy': 432.734,
#     'time_tail_free': 514.799,
#     'time_tail_occupy': 441.2},
#    'rt.buffer_stop.0->DA1': {'time_head_free': 11.418,
#     'time_head_occupy': 0.0,
#     'time_tail_free': 43.529,
#     'time_tail_occupy': 0.0},
#    'rt.DA_out->D0': {'time_head_free': 98.921,
#     'time_head_occupy': 20.876,
#     'time_tail_free': 108.855,
#     'time_tail_occupy': 47.008},
#    'rt.DA2->DA_out': {'time_head_free': 20.876,
#     'time_head_occupy': 11.418,
#     'time_tail_free': 47.008,
#     'time_tail_occupy': 43.529},
#    'rt.D0->D1': {'time_head_free': 156.008,
#     'time_head_occupy': 98.921,
#     'time_tail_free': 180.73,
#     'time_tail_occupy': 108.855},
#    'rt.D2->D3': {'time_head_free': 432.734,
#     'time_head_occupy': 384.427,
#     'time_tail_free': 441.2,
#     'time_tail_occupy': 395.704},
#    'rt.DB_in->DB1': {'time_head_free': 491.036,
#     'time_head_occupy': 488.174,
#     'time_tail_free': 525.2080000000001,
#     'time_tail_occupy': 514.799},
#    'rt.D1->D2': {'time_head_free': 384.427,
#     'time_head_occupy': 156.008,
#     'time_tail_free': 395.704,
#     'time_tail_occupy': 180.73},
#    'rt.DB_in->DB2': {'time_head_free': 491.036,
#     'time_head_occupy': 488.174,
#     'time_tail_free': 525.2080000000001,
#     'time_tail_occupy': 514.799},
#    'rt.DB1->buffer_stop.2': {'time_head_free': 532.533,
#     'time_head_occupy': 491.036,
#     'time_tail_free': 532.533,
#     'time_tail_occupy': 525.2080000000001},
#    'rt.DA1->DA_out': {'time_head_free': 20.876,
#     'time_head_occupy': 11.418,
#     'time_tail_free': 47.008,
#     'time_tail_occupy': 43.529}},
#   'speeds': [{'position': 0.0, 'speed': 0.0, 'time': 0.0},
#    {'position': 0.922252864428832, 'speed': 0.922252864428832, 'time': 2.0},
#    {'position': 3.6877089403523287, 'speed': 1.8432032114946646, 'time': 4.0},
#    {'position': 8.293722075391658, 'speed': 2.7628099235446646, 'time': 6.0},
#    {'position': 14.737564131867863, 'speed': 3.6810321329315396, 'time': 8.0},
#    {'position': 33.12696112343589, 'speed': 5.5128202736486145, 'time': 12.0},
#    {'position': 58.8280247380274, 'speed': 7.336637964500956, 'time': 16.0},
#    {'position': 91.80694364871871, 'speed': 9.151702521168463, 'time': 20.0},
#    {'position': 154.83436374260492, 'speed': 11.85256567893157, 'time': 26.0},
#    {'position': 233.96297684784363, 'speed': 14.51797516481141, 'time': 32.0},
#    {'position': 328.91772568490126, 'speed': 17.119156463497404, 'time': 38.0},
#    {'position': 439.1804084229013, 'speed': 19.6185313566869, 'time': 44.0},
#    {'position': 563.8872106029471, 'speed': 21.902415850299366, 'time': 50.0},
#    {'position': 959.3464399779697, 'speed': 27.50578139824669, 'time': 66.0},
#    {'position': 1443.488407958817, 'speed': 32.99601920421478, 'time': 82.0},
#    {'position': 2014.5180331911379, 'speed': 38.35451543355326, 'time': 98.0},
#    {'position': 2664.466476605495,
#     'speed': 43.422730492157044,
#     'time': 113.88540358638731},
#    {'position': 3106.0, 'speed': 38.0, 'time': 124.7308645707014},
#    {'position': 3461.0, 'speed': 33.0, 'time': 134.73086457070139},
#    {'position': 3766.0, 'speed': 28.0, 'time': 144.73086457070139},
#    {'position': 4066.0, 'speed': 22.0, 'time': 156.73086457070139},
#    {'position': 4261.0, 'speed': 17.0, 'time': 166.73086457070139},
#    {'position': 4354.0, 'speed': 14.0, 'time': 172.73086457070139},
#    {'position': 4429.0, 'speed': 11.0, 'time': 178.73086457070139},
#    {'position': 4469.0, 'speed': 9.0, 'time': 182.73086457070139},
#    {'position': 4514.0, 'speed': 6.0, 'time': 188.73086457070139},
#    {'position': 4525.0, 'speed': 5.0, 'time': 190.73086457070139},
#    {'position': 4541.0, 'speed': 3.0, 'time': 194.73086457070139},
#    {'position': 4546.0, 'speed': 2.0, 'time': 196.73086457070139},
#    {'position': 4549.0, 'speed': 1.0, 'time': 198.73086457070139},
#    {'position': 4550.0, 'speed': 0.0, 'time': 200.73086457070139},
#    {'position': 4550.922252864429,
#     'speed': 0.922252864428832,
#     'time': 302.7308645707014},
#    {'position': 4553.687708940352,
#     'speed': 1.8432032114946646,
#     'time': 304.7308645707014},
#    {'position': 4558.293722075392,
#     'speed': 2.7628099235446646,
#     'time': 306.7308645707014},
#    {'position': 4573.016368557294,
#     'speed': 4.5977722924939375,
#     'time': 310.7308645707014},
#    {'position': 4595.065584085306,
#     'speed': 6.425802688220971,
#     'time': 314.7308645707014},
#    {'position': 4624.4099519150395,
#     'speed': 8.245289212510947,
#     'time': 318.7308645707014},
#    {'position': 4661.014205997204,
#     'speed': 10.055559827317502,
#     'time': 322.7308645707014},
#    {'position': 4755.811150535517,
#     'speed': 13.633851147514424,
#     'time': 330.7308645707014},
#    {'position': 4878.917725684901,
#     'speed': 17.119156463497404,
#     'time': 338.7308645707014},
#    {'position': 5029.215594888602,
#     'speed': 20.416655109014798,
#     'time': 346.7308645707014},
#    {'position': 5350.556102396263,
#     'speed': 25.421627328247766,
#     'time': 360.7308645707014},
#    {'position': 5622.133630424382,
#     'speed': 28.887130252522393,
#     'time': 370.7308645707014},
#    {'position': 5928.176865947894,
#     'speed': 32.31552280670609,
#     'time': 380.7308645707014},
#    {'position': 6564.518033191134,
#     'speed': 38.35451543355326,
#     'time': 398.7308645707014},
#    {'position': 7306.972002537259,
#     'speed': 44.06926083791856,
#     'time': 416.7308645707014},
#    {'position': 8094.125985413449,
#     'speed': 48.947666079053775,
#     'time': 433.6394031856742},
#    {'position': 8726.0, 'speed': 42.0, 'time': 447.5347353437818},
#    {'position': 9194.0, 'speed': 36.0, 'time': 459.5347353437818},
#    {'position': 9590.0, 'speed': 30.0, 'time': 471.5347353437818},
#    {'position': 9914.0, 'speed': 24.0, 'time': 483.5347353437818},
#    {'position': 10049.0, 'speed': 21.0, 'time': 489.5347353437818},
#    {'position': 10166.0, 'speed': 18.0, 'time': 495.5347353437818},
#    {'position': 10265.0, 'speed': 15.0, 'time': 501.5347353437818},
#    {'position': 10346.0, 'speed': 12.0, 'time': 507.5347353437818},
#    {'position': 10409.0, 'speed': 9.0, 'time': 513.5347353437818},
#    {'position': 10454.0, 'speed': 6.0, 'time': 519.5347353437818},
#    {'position': 10465.0, 'speed': 5.0, 'time': 521.5347353437818},
#    {'position': 10481.0, 'speed': 3.0, 'time': 525.5347353437818},
#    {'position': 10486.0, 'speed': 2.0, 'time': 527.5347353437818},
#    {'position': 10489.0, 'speed': 1.0, 'time': 529.5347353437818},
#    {'position': 10490.0, 'speed': 0.0, 'time': 532.5347353437818}],
#   'stops': [{'duration': 100.0, 'position': 4550.0, 'time': 300.7308645707014},
#    {'duration': 1.0, 'position': 10490.0, 'time': 532.5347353437818}]}]

# %%
res[0]['base_simulations'][0]['route_occupancies'].keys()
# Out:
# dict_keys(['rt.D3->DB_in', 'rt.buffer_stop.0->DA1', 'rt.DA_out->D0', 'rt.DA2->DA_out', 'rt.D0->D1', 'rt.D2->D3', 'rt.DB_in->DB1', 'rt.D1->D2', 'rt.DB_in->DB2', 'rt.DB1->buffer_stop.2', 'rt.DA1->DA_out'])

# %%
infr.route_lengths(infra)
infr.route_limits(infra)
# Out:
# {'DA1': ('STA_Q1', 430.0),
#  'DA2': ('STA_Q2', 430.0),
#  'DA_out': ('T', 50.0),
#  'D0': ('T', 2000.0),
#  'D1': ('T', 4000.0),
#  'D2': ('T', 6000.0),
#  'D3': ('T', 8000.0),
#  'DB_in': ('T', 9970.0),
#  'DB1': ('STB_Q1', 30.0),
#  'DB2': ('STB_Q2', 30.0),
#  'buffer_stop.0': ('STA_Q1', 0.0),
#  'buffer_stop.1': ('STA_Q2', 0.0),
#  'buffer_stop.2': ('STB_Q1', 450.0),
#  'buffer_stop.3': ('STB_Q2', 450.0)}

# %%
sim['train_schedules'][0]
# Out:
# {'id': 'train0',
#  'rolling_stock': 'fast_rolling_stock',
#  'departure_time': 0,
#  'initial_head_location': {'track_section': 'STA_Q1', 'offset': 400},
#  'initial_speed': 0.0,
#  'final_head_location': {'track_section': 'STB_Q1', 'offset': 440},
#  'stops': [{'duration': 100,
#    'location': {'track_section': 'T', 'offset': 4500}},
#   {'duration': 1, 'position': -1}],
#  'routes': ['rt.buffer_stop.0->DA1',
#   'rt.DA1->DA_out',
#   'rt.DA_out->D0',
#   'rt.D0->D1',
#   'rt.D1->D2',
#   'rt.D2->D3',
#   'rt.D3->DB_in',
#   'rt.DB_in->DB1',
#   'rt.DB1->buffer_stop.2']}
