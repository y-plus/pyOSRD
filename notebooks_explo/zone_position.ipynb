# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from rlway.pyosrd import OSRD
from rlway.schedules import schedule_from_osrd

# %%
OSRD.use_cases
# Out:
# ['c1',
#  'c1y2',
#  'c2x2',
#  'c2xx2',
#  'c2y13s',
#  'c2y1y2',
#  'c2z2z2',
#  'c3y1',
#  'c3yy1yy3',
#  'cvg_dvg',
#  'point_switch',
#  'station_capacity2',
#  'straight_line']

# %%
sim = OSRD(use_case='cvg_dvg', dir='tmp')
# Out:
# [18:09:22,434] [INFO]  [StandaloneSimulationCommand] Loading infra: tmp/infra.json
# [18:09:22,464] [INFO]              [FullInfra] parsing infra
# [18:09:22,527] [INFO]              [FullInfra] adaptation to kotlin
# [18:09:22,560] [INFO]              [FullInfra] loading signals
# [18:09:22,567] [INFO]              [FullInfra] building blocks
# [18:09:22,571] [INFO]  [StandaloneSimulationCommand] Loading input: tmp/simulation.json
# [18:09:22,584] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.22
# [18:09:22,626] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.23
# [18:09:22,631] [INFO]  [StandaloneSimulationCommand] All simulations completed
# [18:09:22,632] [INFO]  [StandaloneSimulationCommand] Saving results at: tmp/results.json

# %%
schedule = schedule_from_osrd(sim)

# %%
sim.draw_infra_points()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1504x134>

# %%
sim.stop_positions
# Out:
# [{'D0<->buffer_stop.0': {'type': 'station', 'offset': 0.0, 'id': 'station0'},
#   'CVG': {'type': 'switch', 'offset': None},
#   'D2<->D3': {'type': 'signal', 'offset': 1130.0, 'id': 'D2'},
#   'DVG': {'type': 'switch', 'offset': None},
#   'D4<->buffer_stop.2': {'type': 'station',
#    'offset': 1680.0,
#    'id': 'station1'}},
#  {'D1<->buffer_stop.1': {'type': 'station', 'offset': None, 'id': 'station0'},
#   'CVG': {'type': 'switch', 'offset': None},
#   'D2<->D3': {'type': 'signal', 'offset': 1130.0, 'id': 'D2'},
#   'DVG': {'type': 'switch', 'offset': None},
#   'D5<->buffer_stop.3': {'type': 'station', 'offset': None, 'id': 'station1'}}]

# %%
sim.stop_positions[0]['D2<->D3']['offset']
# Out:
# 1130.0
