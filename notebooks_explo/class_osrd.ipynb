# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from rlway.osrd_ import OSRD

# %%
sim = OSRD('../cases/cvg/')

# %%
sim
# Out:
# OSRD(dir='../cases/cvg/', infra_json='infra.json', simulation_json='simulation.json', results_json='results.json')

# %%
sim.results
# Out:
# [{'base_simulations': [{'head_positions': [{'offset': 300.0,
#       'path_offset': 0.0,
#       'time': 0.0,
#       'track_section': 'STA_Q1'},
#      {'offset': 303.6877089403523,
#       'path_offset': 3.6877089403523287,
#       'time': 4.0,
#       'track_section': 'STA_Q1'},
#      {'offset': 323.01636855729333,
#       'path_offset': 23.01636855729334,
#       'time': 10.0,
#       'track_section': 'STA_Q1'},
#      {'offset': 345.0655840853055,
#       'path_offset': 45.065584085305474,
#       'time': 14.0,
#       'track_section': 'STA_Q1'},
#      {'offset': 391.80694364871874,
#       'path_offset': 91.80694364871871,
#       'time': 20.0,
#       'track_section': 'STA_Q1'},
#      {'offset': 432.02578194409773,
#       'path_offset': 132.02578194409776,
#       'time': 24.0,
#       'track_section': 'STA_Q1'},
#      {'offset': 55.81115053551781,
#       'path_offset': 205.8111505355178,
#       'time': 30.0,
#       'track_section': 'T'},
# ...

# %%
sim.routes
# Out:
# ['rt.DA1->DA_out',
#  'rt.buffer_stop.0->DA1',
#  'rt.DA2->DA_out',
#  'rt.buffer_stop.1->DA2',
#  'rt.DA_out->DB_in',
#  'rt.DB_in->buffer_stop.2']

# %%
sim.run()
