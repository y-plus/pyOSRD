# %%
from pyosrd import OSRD
from pyosrd.schedules import schedule_from_osrd, step_has_fixed_duration, step_station_id, step_type

# %%
sim = OSRD(simulation='station_capacity2', dir='/tmp')
# Out:
# [15:46:58,636] [INFO]  [StandaloneSimulationCommand] Loading infra: /tmp/infra.json
# [15:46:58,666] [INFO]              [FullInfra] parsing infra
# [15:46:58,735] [INFO]              [FullInfra] adaptation to kotlin
# [15:46:58,767] [INFO]              [FullInfra] loading signals
# [15:46:58,773] [INFO]              [FullInfra] building blocks
# [15:46:58,778] [INFO]  [StandaloneSimulationCommand] Loading input: /tmp/simulation.json
# [15:46:58,938] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.2
# [15:46:59,014] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.3
# [15:46:59,021] [INFO]  [StandaloneSimulationCommand] All simulations completed
# [15:46:59,021] [INFO]  [StandaloneSimulationCommand] Saving results at: /tmp/results.json

# %%
sim.draw_infra_points()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1372x134>

# %%
schedule = schedule_from_osrd(sim)
#schedule.draw_graph()

# %%
schedule.plot()
# Out:
# <Axes: xlabel='Time'>

# %% [markdown]
# # Infos supplémentaires sur les zones
# Peuvent être utiles aux agents

# %%
display(step_has_fixed_duration(sim))
display(step_station_id(sim))
display(step_type(sim))
# Out:
#                    train0 train1
# D0<->buffer_stop.0  False  False
# DVG                  True   True
# D1<->D3             False    NaN
# D2<->D4               NaN  False
# CVG                  True   True
# D5<->buffer_stop.5   True   True
#                      train0   train1
# D0<->buffer_stop.0      NaN      NaN
# DVG                     NaN      NaN
# D1<->D3             station      NaN
# D2<->D4                 NaN  station
# CVG                     NaN      NaN
# D5<->buffer_stop.5      NaN      NaN
#                        train0     train1
# D0<->buffer_stop.0     signal     signal
# DVG                    switch     switch
# D1<->D3               station        NaN
# D2<->D4                   NaN    station
# CVG                    switch     switch
# D5<->buffer_stop.5  last_zone  last_zone

# %% [markdown]
# # Weights
# Construire des matrices de pondération pour les passer à un agent qui s'en servira pour le calcul d'un retard pondéré

# %%
import pyosrd.schedules.weights as weights

display(weights.stations_only(sim))
display(weights.all_steps(sim))
# Out:
#                     train0  train1
# D0<->buffer_stop.0       0       0
# DVG                      0       0
# D1<->D3                  1       0
# D2<->D4                  0       1
# CVG                      0       0
# D5<->buffer_stop.5       0       0
#                     train0  train1
# D0<->buffer_stop.0       1       1
# DVG                      1       1
# D1<->D3                  1       0
# D2<->D4                  0       1
# CVG                      1       1
# D5<->buffer_stop.5       1       1

# %%
w = weights.stations_only(sim)
w.weights.train(0, 2)
w.weights.train_zone(1, 'D0<->buffer_stop.0', 5)
w.weights.train_station_sim(1, 'station', 7, sim)
w
# Out:
# /home/simon/dev/python/pyOSRD/src/pyosrd/schedules/weights.py:80: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   osrd._obj[train].loc[zone] = value
# /home/simon/dev/python/pyOSRD/src/pyosrd/schedules/weights.py:80: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   osrd._obj[train].loc[zone] = value
#                     train0  train1
# D0<->buffer_stop.0       0       5
# DVG                      0       0
# D1<->D3                  2       0
# D2<->D4                  0       7
# CVG                      0       0
# D5<->buffer_stop.5       0       0

# %% [markdown]
# # Scheduler Agents
# C'est une classe abstraite qui a tous les outils pour travailler avec des schedules
# 1. de manière autonome à partir d'une simulation,
# 2. ou dans la méthode regulate(),
# 3. ou encore de manière autonome à partir de schedules custom.
#
# Une classe concrète doit avoir une méthode qui renvoie les délais ajoutés pour chaque couple (zone, train) sous forme d'un dataframe avec les mêmes dimensions qu'un schedule.
# ```python3
# @property
# def steps_extra_delays(self) -> pd.DataFrame
# ```

# %% [markdown]
# ## 1. de manière autonome à partir d'une simulation

# %%
from pyosrd.agents.scheduler_agent import SchedulerAgent
import pandas as pd

class DummySchedulerAgent(SchedulerAgent):
    @property
    def steps_extra_delays(self) -> pd.DataFrame:
        """As an example, make train1 stop 60s more at station"""
        extra_delays = self.ref_schedule.durations * 0.
        extra_delays.iloc[3][1] = 60.
        return extra_delays

sim.reset_delays()
sim.add_delay('train0', time_threshold=90, delay=280.)
agent = DummySchedulerAgent('from_sim')
agent.set_schedules_from_osrd(sim)

# %%
display(agent.step_has_fixed_duration)
display(agent.weights)
# Out:
#                    train0 train1
# D0<->buffer_stop.0  False  False
# DVG                  True   True
# D1<->D3             False    NaN
# D2<->D4               NaN  False
# CVG                  True   True
# D5<->buffer_stop.5   True   True
#                     train0  train1
# D0<->buffer_stop.0       0       0
# DVG                      0       0
# D1<->D3                  1       0
# D2<->D4                  0       1
# CVG                      0       0
# D5<->buffer_stop.5       0       0

# %%
agent.ref_schedule.plot()
agent.delayed_schedule.plot()
agent.regulated_schedule.plot()
# Out:
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   extra_delays.iloc[3][1] = 60.
# <Axes: xlabel='Time'>

# %%
agent.steps_extra_delays
# Out:
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   extra_delays.iloc[3][1] = 60.
#                     train0  train1
# D0<->buffer_stop.0     0.0     0.0
# DVG                    0.0     0.0
# D1<->D3                0.0     NaN
# D2<->D4                NaN    60.0
# CVG                    0.0     0.0
# D5<->buffer_stop.5     0.0     0.0

# %% [markdown]
# ## 2. via la méthode regulate de la classe OSRD()

# %%
sim.regulate(agent=agent).space_time_chart(1);
# Out:
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[3][1] = 60.
# /tmp/ipykernel_817369/3254144145.py:9: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   extra_delays.iloc[3][1] = 60.
# [15:47:00,563] [INFO]  [StandaloneSimulationCommand] Loading infra: /tmp/infra.json
# [15:47:00,593] [INFO]              [FullInfra] parsing infra
# [15:47:00,662] [INFO]              [FullInfra] adaptation to kotlin
# [15:47:00,691] [INFO]              [FullInfra] loading signals
# [15:47:00,696] [INFO]              [FullInfra] building blocks
# [15:47:00,701] [INFO]  [StandaloneSimulationCommand] Loading input: /tmp/delayed/from_sim/simulation.json
# [15:47:00,868] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.2
# [15:47:00,944] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.3
# [15:47:00,950] [INFO]  [StandaloneSimulationCommand] All simulations completed
# [15:47:00,950] [INFO]  [StandaloneSimulationCommand] Saving results at: /tmp/delayed/from_sim/results.json

# %% [markdown]
# ## 3. de manière autonome à partir de schedules custom

# %%
from pyosrd.schedules import Schedule

schedule = Schedule(6, 2)

schedule.df.at[0, 0] = [0, 1]
schedule.df.at[2, 0] = [1, 2]
schedule.df.at[3, 0] = [2, 3]
schedule.df.at[4, 0] = [3, 4]

schedule.df.at[1, 1] = [1, 2]
schedule.df.at[2, 1] = [2, 3]
schedule.df.at[3, 1] = [3, 4]
schedule.df.at[5, 1] = [4, 5]

delayed = schedule.add_delay(0, 2, .5)

# %%
schedule.draw_graph()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=260x134>

# %%
schedule.plot()
delayed.plot()
# Out:
# <Axes: xlabel='Time'>

# %%
class TestSchedulerAgent(SchedulerAgent):
    @property
    def steps_extra_delays(self) -> pd.DataFrame:
        """As an example, make train0 star 1 time unit later"""
        extra_delays = self.ref_schedule.durations * 0.
        extra_delays.iloc[1][1] = 1.
        return extra_delays

agent=TestSchedulerAgent(
    'directly_from_schedules',
    ref_schedule=schedule,
    delayed_schedule=delayed,
    # one could had fixed duration zones and/or weights
)

# %%
agent.steps_extra_delays
# Out:
# /tmp/ipykernel_817369/4223396617.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[1][1] = 1.
#      0    1
# 0  0.0  NaN
# 1  NaN  1.0
# 2  0.0  0.0
# 3  0.0  0.0
# 4  0.0  NaN
# 5  NaN  0.0

# %%
agent.regulated_schedule.plot()
# Out:
# /tmp/ipykernel_817369/4223396617.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[1][1] = 1.
# /tmp/ipykernel_817369/4223396617.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[1][1] = 1.
# /tmp/ipykernel_817369/4223396617.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   extra_delays.iloc[1][1] = 1.
# <Axes: xlabel='Time'>
