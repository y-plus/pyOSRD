# %% [markdown]
# # Tutorial pyOSRD #3
# Use an existing simulation

# %%
from pyosrd import OSRD

# %% [markdown]
# 1. Create the simulation by indicating the folder containing `infra.json` and `simulation.json`

# %%
sim = OSRD(
    dir='existing_simulation'
)

# %% [markdown]
# 2. Inspect it

# %%
# sim.draw_infra_points()

# %%
sim.num_stations, sim.track_section_lengths
# Out:
# (1,
#  {'T0': 1000.0,
#   'T1': 1000.0,
#   'T2': 1000.0,
#   'T3': 1000.0,
#   'T4': 1000.0,
#   'T5': 1000.0})

# %%
sim.trains, sim.num_trains
# Out:
# (['train0', 'train1'], 2)

# %%
sim.train_lengths
# Out:
# [400, 400]

# %% [markdown]
# 3. Run the simulation

# %%
sim.run()
# Out:
# [16:33:29,376] [INFO]  [StandaloneSimulationCommand] Loading infra: existing_simulation/infra.json
# [16:33:29,411] [INFO]              [FullInfra] parsing infra
# [16:33:29,411] [INFO]              [FullInfra] adaptation to kotlin
# [16:33:29,455] [INFO]              [FullInfra] loading signals
# [16:33:29,458] [INFO]              [FullInfra] building blocks
# [16:33:29,481] [INFO]  [StandaloneSimulationCommand] Loading input: existing_simulation/simulation.json
# [16:33:29,704] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.2
# [16:33:29,816] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.3
# [16:33:29,822] [INFO]  [StandaloneSimulationCommand] All simulations completed
# [16:33:29,822] [INFO]  [StandaloneSimulationCommand] Saving results at: existing_simulation/results.json

# %% [markdown]
# 4. Inspect the results

# %%
sim.space_time_chart_plotly(train=0,eco_or_base='base', points_to_show=['station'])
# Out:
# <div>                            <div id="ce1cf25f-3fd8-45fc-82b1-0ae4831bc1be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce1cf25f-3fd8-45fc-82b1-0ae4831bc1be")) {                    Plotly.newPlot(                        "ce1cf25f-3fd8-45fc-82b1-0ae4831bc1be",                        [{"customdata":["00:00:00","00:00:06","00:00:12","00:00:18","00:00:24","00:00:30","00:00:36","00:00:42","00:00:48","00:00:54","00:01:00","00:01:02","00:01:07","00:01:10","00:01:13","00:01:18","00:01:24","00:01:32","00:01:40","00:01:51","00:01:58","00:01:59","00:02:04","00:02:07","00:02:10","00:02:11","00:02:17","00:02:23","00:02:29","00:02:35","00:02:41","00:02:47","00:02:53","00:02:59","00:03:07"],"hovertemplate":"%{customdata} (%{y:.0f} m)","line":{"color":"blac
# ...

# %%
sim.space_time_chart_plotly(
    train=1,
    eco_or_base='base',
    points_to_show=['departure', 'arrival', 'signal']
)
# Out:
# <div>                            <div id="fe3ca992-a514-4947-97bd-77346122cb0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe3ca992-a514-4947-97bd-77346122cb0e")) {                    Plotly.newPlot(                        "fe3ca992-a514-4947-97bd-77346122cb0e",                        [{"customdata":["00:00:00","00:00:06","00:00:12","00:00:18","00:00:24","00:00:30","00:00:36","00:00:42","00:00:48","00:00:54","00:01:00","00:01:02","00:01:07","00:01:10","00:01:13","00:01:18","00:01:24","00:01:32","00:01:40","00:01:51","00:01:58","00:01:59","00:02:04","00:02:07","00:02:10","00:02:11","00:02:17","00:02:23","00:02:29","00:02:35","00:02:41","00:02:47","00:02:53","00:02:59","00:03:07"],"hovertemplate":"%{customdata} (%{y:.0f} m)","line":{"width":1.5},
# ...

# %%
sim.train_departure(0), sim.train_arrival(0)
# Out:
# (Point(track_section='T0', position=10.0, id='departure_train0', type='departure'),
#  Point(track_section='T5', position=990.0, id='arrival_train0', type='arrival'))

# %%
sim.points_encountered_by_train(0)
# Out:
# [{'id': 'departure_train0',
#   'offset': 0.0,
#   'type': 'departure',
#   't_base': 0.0,
#   't_tail_base': 41.95646125062055},
#  {'id': 'S0',
#   'offset': 790.0,
#   'type': 'signal',
#   't_base': 59.48809903736671,
#   't_tail_base': 73.89488368923085},
#  {'id': 'D0',
#   'offset': 810.0,
#   'type': 'detector',
#   't_base': 60.29713485185037,
#   't_tail_base': 74.55578190867286},
#  {'id': 'DVG',
#   'offset': 990.0,
#   'type': 'switch',
#   't_base': 67.01383110325345,
#   't_tail_base': 80.32036304556156},
#  {'id': 'D1',
#   'offset': 1170.0,
#   'type': 'detector',
#   't_base': 73.23398546978885,
#   't_tail_base': 85.70863598971498},
#  {'id': 'station/T3',
#   'offset': 2780.0,
#   'type': 'station',
#   't_base': 117.97652314718277,
#   't_tail_base': 130.64702123147396},
#  {'id': 'S3',
#   'offset': 2790.0,
#   'type': 'signal',
#   't_base': 118.25430092496056,
#   't_tail_base': 130.99184881768088},
#  {'id': 'D3',
#   'offset': 2810.0,
# ...
