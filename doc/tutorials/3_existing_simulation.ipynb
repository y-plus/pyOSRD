# %% [markdown]
# # Tutorial pyOSRD #3
# Use an existing simulation

# %%
from pyosrd import OSRD

# %% [markdown]
# 1. Create the simulation by indicating the folder containing `infra.json` and `simulation.json`

# %%
sim = OSRD(
    dir='existing_simulation'
)

# %% [markdown]
# 2. Inspect it

# %%
sim.draw_infra_points()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=714x302>

# %%
sim.num_stations, sim.track_section_lengths
# Out:
# (1,
#  {'T0': 1000.0,
#   'T1': 1000.0,
#   'T2': 1000.0,
#   'T3': 1000.0,
#   'T4': 1000.0,
#   'T5': 1000.0})

# %%
sim.trains, sim.num_trains
# Out:
# (['train0', 'train1'], 2)

# %%
sim.train_lengths
# Out:
# [400, 400]

# %% [markdown]
# 3. Run the simulation

# %%
sim.run()
# Out:
# [18:25:05,217] [INFO]  [StandaloneSimulationCommand] Loading infra: existing_simulation/infra.json
# [18:25:05,251] [INFO]              [FullInfra] parsing infra
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/pyOSRD/src/pyosrd/osrd.py:182, in OSRD.run(self)
#     181 try:
# --> 182     self.results = _read_json(
#     183         os.path.join(self.dir, self.results_json)
#     184     )
#     185 except FileNotFoundError:
#
# File ~/pyOSRD/src/pyosrd/osrd.py:26, in _read_json(json_file)
#      25 def _read_json(json_file: str) -> dict | list:
# ---> 26     with open(json_file, 'r') as f:
#      27         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'existing_simulation/results.json'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sim.run()
#
# File ~/pyOSRD/src/pyosrd/osrd.py:186, in OSRD.run(self)
#     182     self.results = _read_json(
#     183         os.path.join(self.dir, self.results_json)
#     184     )
#     185 except FileNotFoundError:
# --> 186     raise RuntimeError(output.stderr.decode())
#
# RuntimeError: Exception in thread "main" java.lang.NullPointerException: Cannot read field "groups" because "switchType" is null
# 	at fr.sncf.osrd.infra.implementation.tracks.undirected.UndirectedInfraBuilder.parseSwitch(UndirectedInfraBuilder.java:447)
# 	at fr.sncf.osrd.infra.implementation.tracks.undirected.UndirectedInfraBuilder.parse(UndirectedInfraBuilder.java:148)
# 	at fr.sncf.osrd.infra.implementation.tracks.undirected.UndirectedInfraBuilder.parseInfra(UndirectedInfraBuilder.java:119)
# 	at fr.sncf.osrd.infra.implementation.tracks.directed.DirectedInfraBuilder.fromRJS(DirectedInfraBuilder.java:61)
# 	at fr.sncf.osrd.infra.implementation.reservation.ReservationInfraBuilder.fromRJS(ReservationInfraBuilder.java:76)
# 	at fr.sncf.osrd.infra.implementation.signaling.SignalingInfraBuilder.fromRJSInfra(SignalingInfraBuilder.java:55)
# 	at fr.sncf.osrd.api.FullInfra.fromRJSInfra(FullInfra.java:31)
# 	at fr.sncf.osrd.cli.StandaloneSimulationCommand.loadInfra(StandaloneSimulationCommand.java:146)
# 	at fr.sncf.osrd.cli.StandaloneSimulationCommand.run(StandaloneSimulationCommand.java:81)
# 	at fr.sncf.osrd.App.main(App.java:42)

# %% [markdown]
# 4. Inspect the results

# %%
sim.draw_infra_points()

# %%
sim.space_time_chart_plotly(train=0, points_to_show=['station'])

# %%
sim.space_time_chart_plotly(
    train=1,
    points_to_show=['departure', 'arrival', 'signal']
)

# %%
sim.train_departure(0), sim.train_arrival(0)

# %%
sim.points_encountered_by_train(0)
