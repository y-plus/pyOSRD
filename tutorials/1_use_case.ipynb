# %% [markdown]
# # Tutorial pyOSRD #1
# Use a predefined use-case

# %%
from rlway.pyosrd import OSRD

# %%
OSRD.use_cases
# Out:
# ['c1',
#  'c1_with_blocks',
#  'c1y2',
#  'c2x2',
#  'c2xx2',
#  'c2y13s',
#  'c2y1sy2sy1s',
#  'c2y1y2',
#  'c2z2z2',
#  'c3y1',
#  'c3yy1yy3',
#  'cvg_dvg',
#  'point_switch',
#  'station_capacity2',
#  'straight_line']

# %%
use_case='c1_with_blocks'
sim = OSRD(use_case=use_case, dir='tmp')
# Out:
# [09:02:28,509] [INFO]  [StandaloneSimulationCommand] Loading infra: tmp/infra.json
# [09:02:28,542] [INFO]              [FullInfra] parsing infra
# [09:02:28,608] [INFO]              [FullInfra] adaptation to kotlin
# [09:02:28,645] [INFO]              [FullInfra] loading signals
# [09:02:28,652] [INFO]              [FullInfra] building blocks
# [09:02:28,657] [INFO]  [StandaloneSimulationCommand] Loading input: tmp/simulation.json
# [09:02:28,670] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.2
# [09:02:28,715] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.3
# [09:02:28,722] [INFO]  [StandaloneSimulationCommand] All simulations completed
# [09:02:28,722] [INFO]  [StandaloneSimulationCommand] Saving results at: tmp/results.json

# %%
sim.draw_infra_points()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1904x44>

# %%
print(sim.num_stations)
print(sim.trains)
print(sim.num_trains)
# Out:
# 2
# ['train0', 'train1']
# 2

# %% [markdown]
# with plotly

# %%
sim.space_time_chart_plotly(1, points_to_show=['switch','station', 'signal'], eco_or_base='base')
# Out:
# <div>                            <div id="e623a28f-cab4-4e52-bbbf-9bb3840b0fc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e623a28f-cab4-4e52-bbbf-9bb3840b0fc2")) {                    Plotly.newPlot(                        "e623a28f-cab4-4e52-bbbf-9bb3840b0fc2",                        [{"name":"train0","x":[0.0,0.1,0.23333333333333334,0.36666666666666664,0.5,0.6333333333333333,0.8,0.9666666666666667,1.1344348698043367,1.2344348698043366,1.3344348698043367,1.46776820313767,1.6011015364710033,1.7344348698043366,1.86776820313767,2.01776820313767],"y":[null,null,null,null,205.8111505355178,328.91772568490126,520.8085223751327,750.4119675638053,1014.0,1161.0,null,null,null,null,null,null],"type":"scatter"},{"name":"train1","x":[1.6666666666666667,1.7666666666666666,1.9,2.033333333333333,2.1666666666666665,2.3,2.466666666666667,2.6333333333333333,2.7949908909975916,2.8949908909975917,2.9949908909975917,3.128324224330925,3.2616575576642584,3.3949908909975917,3.528324224330925,3.678324224330925],"y":[0.0,8.293722075391656,45.06558408530549,111.01420599720467,205.8111505355178,328.91772568490126,520.8085223751327,750.4119675638053,1004.0,1151.0,1280.0,1424.0,1536.0,1616.0,1664.0,1680.0],"type":"scatter"}],                        {"hovermode":"x unified","template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0, ...

# %% [markdown]
# with matplotlib

# %%
sim.space_time_chart(0)
# Out:
# <Axes: title={'center': 'train0 (base)'}, xlabel='Time [min]'>

# %% [markdown]
# Extract informations about the trains trajectories

# %%
sim.points_encountered_by_train(0)
# Out:
# [{'id': 'departure_First train',
#   'offset': 0.0,
#   'type': 'departure',
#   't_base': 0.0,
#   't_tail_base': 41.70430867666085,
#   't_eco': 0.0,
#   't_tail_eco': 44.070663051846765},
#  {'id': 'stationA',
#   'offset': 0.0,
#   'type': 'station',
#   't_base': 0.0,
#   't_tail_base': 41.70430867666085,
#   't_eco': 0.0,
#   't_tail_eco': 44.070663051846765},
#  {'id': 'SA',
#   'offset': 20.0,
#   'type': 'signal',
#   't_base': 9.144667412541061,
#   't_tail_base': 42.74656814636778,
#   't_eco': 9.663547222036541,
#   't_tail_eco': 45.17206162095327},
#  {'id': 'DA',
#   'offset': 40.0,
#   'type': 'detector',
#   't_base': 12.998915836005082,
#   't_tail_base': 43.7888276160747,
#   't_eco': 13.73649049764714,
#   't_tail_eco': 46.27346019005978},
#  {'id': 'S2.0',
#   'offset': 1520.0,
#   'type': 'signal',
#   't_base': 84.2837169974451,
#   't_tail_base': 95.49676421130924,
#   't_eco': 89.06607999068301,
#   't_tail_eco': 100.91536945806142},
#  {'id': 'D2',
#   'offset': 1540.0,
#   'type': 'detector',
#   't_base': 84.86030604107967,
#   't_tail_base': 96.03961218002453,
#   't_eco': 89.67538541421654,
#   't_tail_eco': 101.4890192960941},
#  {'id': 'S4.0',
#   'offset': 3520.0,
#   'type': 'signal',
#   't_base': 132.3144495184848,
#   't_tail_base': 140.41184947268212,
#   't_eco': 139.82213604905192,
#   't_tail_eco': 148.3789925538375},
#  {'id': 'D4',
#   'offset': 3540.0,
#   'type': 'detector',
#   't_base': 132.725230905739,
#   't_tail_base': 140.80343548726853,
#   't_eco': 140.256225683435,
#   't_tail_eco': 148.79279764621901},
#  {'id': 'S6.0',
#   'offset': 5520.0,
#   'type': 'signal',
#   't_base': 169.7979536616337,
#   't_tail_base': 176.71172103053095,
#   't_eco': 179.43250086537822,
#   't_tail_eco': 186.738563998947},
#  {'id': 'D6',
#   'offset': 5540.0,
#   'type': 'detector',
#   't_base': 170.14364203007855,
#   't_tail_base': 177.0574093989758,
#   't_eco': 179.79780402205665,
#   't_tail_eco': 187.10386715562544},
#  {'id': 'S8.0',
#   'offset': 7520.0,
#   'type': 'signal',
#   't_base': 207.51857531112725,
#   't_tail_base': 217.14287854412615,
#   't_eco': 219.29343753045114,
#   't_tail_eco': 229.46383570630348},
#  {'id': 'D8',
#   'offset': 7540.0,
#   'type': 'detector',
#   't_base': 207.9533579198229,
#   't_tail_base': 217.65569905694664,
#   't_eco': 219.75289024544966,
#   't_tail_eco': 230.00575429322484},
#  {'id': 'SB',
#   'offset': 9020.0,
#   'type': 'signal',
#   't_base': 253.17667807792566,
#   't_tail_base': 280.66531444156203,
#   't_eco': 267.5422378695934,
#   't_tail_eco': 296.59061367001794},
#  {'id': 'DB',
#   'offset': 9040.0,
#   'type': 'detector',
#   't_base': 254.09159649284408,
#   't_tail_base': 283.67667807792566,
#   't_eco': 268.5090698939872,
#   't_tail_eco': 299.77284582674076},
#  {'id': 'stationB',
#   'offset': 9480.0,
#   'type': 'station',
#   't_base': 297.04031444156203,
#   't_tail_base': 297.04031444156203,
#   't_eco': 313.8380103041537,
#   't_tail_eco': 313.8380103041537},
#  {'id': 'arrival_First train',
#   'offset': 9480.0,
#   'type': 'arrival',
#   't_base': 297.04031444156203,
#   't_tail_base': 297.04031444156203,
#   't_eco': 313.8380103041537,
#   't_tail_eco': 313.8380103041537}]
