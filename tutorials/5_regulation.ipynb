# %%
from pyosrd import OSRD
from pyosrd.schedules import schedule_from_osrd


sim = OSRD(use_case='station_capacity2', dir='station_capacity2')
# Out:
# [11:18:10,411] [INFO]  [StandaloneSimulationCommand] Loading infra: station_capacity2/infra.json
# [11:18:10,442] [INFO]              [FullInfra] parsing infra
# [11:18:10,506] [INFO]              [FullInfra] adaptation to kotlin
# [11:18:10,540] [INFO]              [FullInfra] loading signals
# [11:18:10,546] [INFO]              [FullInfra] building blocks
# [11:18:10,550] [INFO]  [StandaloneSimulationCommand] Loading input: station_capacity2/simulation.json
# [11:18:10,562] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.0
# [11:18:10,609] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.1
# [11:18:10,614] [INFO]  [StandaloneSimulationCommand] All simulations completed
# [11:18:10,614] [INFO]  [StandaloneSimulationCommand] Saving results at: station_capacity2/results.json

# %%
sim.draw_infra_points()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1372x134>

# %%
sim.space_time_chart(0)
# Out:
# <Axes: title={'center': 'train0 (base)'}, xlabel='Time [min]'>

# %%
schedule_from_osrd(sim).plot()
# Out:
# <Axes: xlabel='Time'>

# %%
sim.reset_delays()
sim.add_delay('train0',100, 280)

# %%
delayed = sim.delayed()

# %%
delayed.space_time_chart(0)
# Out:
# <Axes: title={'center': 'train0 (base)'}, xlabel='Time [min]'>

# %%
schedule_from_osrd(delayed).plot()
# Out:
# <Axes: xlabel='Time'>

# %%
# regulated = sim.regulate(agent=agent)

# %%
# schedule_from_osrd(regulated).plot()

# %%
# regulated.space_time_chart(1)
