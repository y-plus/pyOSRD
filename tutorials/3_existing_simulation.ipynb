# %% [markdown]
# # Tutorial pyOSRD #3
# Use an existing simulation

# %%
from rlway.pyosrd import OSRD

# %% [markdown]
# 1. Create the simulation by indicating the folder containing `infra.json` and `simulation.json`

# %%
sim = OSRD(
    dir='simulation'
)

# %% [markdown]
# 2. Inspect it

# %%
sim.draw_infra_points()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1504x134>

# %%
sim.num_stations, sim.track_section_lengths
# Out:
# (2,
#  {'T0': 500.0,
#   'T1': 500.0,
#   'T2': 500.0,
#   'T3': 500.0,
#   'T4': 500.0,
#   'T5': 500.0})

# %%
sim.trains, sim.num_trains
# Out:
# (['train0', 'train1'], 2)

# %%
sim.train_lengths
# Out:
# [400, 400]

# %% [markdown]
# 3. Run the simulation

# %%
sim.run()
# Out:
# [09:06:23,116] [INFO]  [StandaloneSimulationCommand] Loading infra: simulation/infra.json
# [09:06:23,154] [INFO]              [FullInfra] parsing infra
# [09:06:23,231] [INFO]              [FullInfra] adaptation to kotlin
# [09:06:23,266] [INFO]              [FullInfra] loading signals
# [09:06:23,272] [INFO]              [FullInfra] building blocks
# [09:06:23,277] [INFO]  [StandaloneSimulationCommand] Loading input: simulation/simulation.json
# [09:06:23,292] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.2
# [09:06:23,352] [INFO]  [StandaloneSimulationCommand] Running simulation for schedule group: group.3
# [09:06:23,360] [INFO]  [StandaloneSimulationCommand] All simulations completed
# [09:06:23,360] [INFO]  [StandaloneSimulationCommand] Saving results at: simulation/results.json

# %% [markdown]
# 4. Inspect the results

# %%
sim.space_time_chart_plotly(train=0, points_to_show=['station'])
# Out:
# <div>                            <div id="e056a419-40e6-43d1-bac8-4adadfbff9fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e056a419-40e6-43d1-bac8-4adadfbff9fd")) {                    Plotly.newPlot(                        "e056a419-40e6-43d1-bac8-4adadfbff9fd",                        [{"name":"train0","x":[0.0,0.1,0.23333333333333334,0.36666666666666664,0.5,0.6333333333333333,0.8,0.9666666666666667,1.1344348698043367,1.2344348698043366,1.3344348698043367,1.46776820313767,1.6011015364710033,1.7344348698043366,1.86776820313767,2.01776820313767],"y":[null,null,null,null,205.8111505355178,328.91772568490126,520.8085223751327,750.4119675638053,1014.0,1161.0,null,null,null,null,null,null],"type":"scatter"},{"name":"train1","x":[1.6666666666666667,1.7666666666666666,1.9,2.033333333333333,2.1666666666666665,2.3,2.466666666666667,2.6333333333333333,2.7949908909975916,2.8949908909975917,2.9949908909975917,3.128324224330925,3.2616575576642584,3.3949908909975917,3.528324224330925,3.678324224330925],"y":[0.0,8.293722075391656,45.06558408530549,111.01420599720467,205.8111505355178,328.91772568490126,520.8085223751327,750.4119675638053,1004.0,1151.0,1280.0,1424.0,1536.0,1616.0,1664.0,1680.0],"type":"scatter"}],                        {"hovermode":"x unified","template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0, ...

# %%
sim.space_time_chart_plotly(
    train=1,
    points_to_show=['departure', 'arrival', 'signal']
)
# Out:
# <div>                            <div id="0e3c0dc1-b9f1-4dd0-a2d1-c86b3e745c2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e3c0dc1-b9f1-4dd0-a2d1-c86b3e745c2d")) {                    Plotly.newPlot(                        "0e3c0dc1-b9f1-4dd0-a2d1-c86b3e745c2d",                        [{"name":"train0","x":[0.0,0.1,0.23333333333333334,0.36666666666666664,0.5,0.6333333333333333,0.8,0.9666666666666667,1.1344348698043367,1.2344348698043366,1.3344348698043367,1.46776820313767,1.6011015364710033,1.7344348698043366,1.86776820313767,2.01776820313767],"y":[null,null,null,null,205.8111505355178,328.91772568490126,520.8085223751327,750.4119675638053,1014.0,1161.0,null,null,null,null,null,null],"type":"scatter"},{"name":"train1","x":[1.6666666666666667,1.7666666666666666,1.9,2.033333333333333,2.1666666666666665,2.3,2.466666666666667,2.6333333333333333,2.7949908909975916,2.8949908909975917,2.9949908909975917,3.128324224330925,3.2616575576642584,3.3949908909975917,3.528324224330925,3.678324224330925],"y":[0.0,8.293722075391656,45.06558408530549,111.01420599720467,205.8111505355178,328.91772568490126,520.8085223751327,750.4119675638053,1004.0,1151.0,1280.0,1424.0,1536.0,1616.0,1664.0,1680.0],"type":"scatter"}],                        {"hovermode":"x unified","template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0, ...

# %%
sim.train_departure(0), sim.train_arrival(0)
# Out:
# (Point(track_section='T0', position=300.0, id='departure_train0', type='departure'),
#  Point(track_section='T4', position=490.0, id='arrival_train0', type='arrival'))

# %%
sim.points_encountered_by_train(0)
# Out:
# [{'id': 'departure_train0',
#   'offset': 0.0,
#   'type': 'departure',
#   't_base': 0.0,
#   't_tail_base': 41.70430867666085},
#  {'id': 'station0',
#   'offset': 0.0,
#   'type': 'station',
#   't_base': 0.0,
#   't_tail_base': 41.70430867666085},
#  {'id': 'S0',
#   'offset': 130.0,
#   'type': 'signal',
#   't_base': 23.60222834989134,
#   't_tail_base': 48.40031967365796},
#  {'id': 'D0',
#   'offset': 150.0,
#   'type': 'detector',
#   't_base': 25.29004646237633,
#   't_tail_base': 49.271386742515105},
#  {'id': 'CVG',
#   'offset': 200.0,
#   'type': 'switch',
#   't_base': 29.50959174358881,
#   't_tail_base': 51.44905441465798},
#  {'id': 'D2',
#   'offset': 250.0,
#   'type': 'detector',
#   't_base': 32.871583384452784,
#   't_tail_base': 53.626722086800854},
#  {'id': 'S3',
#   'offset': 1130.0,
#   'type': 'signal',
#   't_base': 72.80078606581122,
#   't_tail_base': 94.92323504540306},
#  {'id': 'D3',
#   'offset': 1150.0,
#   'type': 'detector',
#   't_base': 73.61711259642347,
#   't_tail_base': 96.4660921882602},
#  {'id': 'DVG',
#   'offset': 1200.0,
#   'type': 'switch',
#   't_base': 75.88004567663229,
#   't_tail_base': 101.4660921882602},
#  {'id': 'D4',
#   'offset': 1250.0,
#   'type': 'detector',
#   't_base': 78.20562707198113,
#   't_tail_base': 108.0660921882602},
#  {'id': 'station1',
#   'offset': 1680.0,
#   'type': 'station',
#   't_base': 115.4410921882602,
#   't_tail_base': 121.0660921882602},
#  {'id': 'arrival_train0',
#   'offset': 1690.0,
#   'type': 'arrival',
#   't_base': 121.0660921882602,
#   't_tail_base': 121.0660921882602}]
